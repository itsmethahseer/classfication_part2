# %% [markdown]
# # This Analysis is for Predicting the Emplooyee Is leave the company or Not.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("files/watson_healthcare_modified.csv")
df.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel  DailyRate  Department  \
# 0     1313919   41        No      Travel_Rarely       1102  Cardiology
# 1     1200302   49        No  Travel_Frequently        279   Maternity
# 2     1060315   37       Yes      Travel_Rarely       1373   Maternity
# 3     1272912   33        No  Travel_Frequently       1392   Maternity
# 4     1414939   27        No      Travel_Rarely        591   Maternity
#
#    DistanceFromHome  Education EducationField  EmployeeCount  ...  \
# 0                 1          2  Life Sciences              1  ...
# 1                 8          1  Life Sciences              1  ...
# 2                 2          2          Other              1  ...
# 3                 3          4  Life Sciences              1  ...
# 4                 2          1        Medical              1  ...
#
#    RelationshipSatisfaction StandardHours  Shift  TotalWorkingYears  \
# 0                         1            80      0                  8
# ...

# %%
df.shape
# Out:
# (1676, 35)

# %%
df.describe()
# Out:
#          EmployeeID          Age    DailyRate  DistanceFromHome    Education  \
# count  1.676000e+03  1676.000000  1676.000000       1676.000000  1676.000000
# mean   1.456796e+06    36.866348   800.557876          9.221957     2.907518
# std    2.487486e+05     9.129126   401.594438          8.158118     1.025835
# min    1.025177e+06    18.000000   102.000000          1.000000     1.000000
# 25%    1.235832e+06    30.000000   465.000000          2.000000     2.000000
# 50%    1.464606e+06    36.000000   796.500000          7.000000     3.000000
# 75%    1.667992e+06    43.000000  1157.000000         14.000000     4.000000
# max    1.886378e+06    60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count         1676.0              1676.000000  1676.000000     1676.000000
# mean             1.0                 2.714797    65.470167        2.724940
# ...

# %%
df.isna().sum()
# Out:
# EmployeeID                  0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# Shift                       0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
attrition_count = pd.DataFrame(df.Attrition.value_counts())
attrition_count
# Out:
#      Attrition
# No        1477
# Yes        199

# %% [markdown]
# So this dataset represents that most of them are like to stay in the company

# %%
plt.pie(attrition_count['Attrition'],labels=["Yes","No"],explode=(0.2,0))
# Out:
# ([<matplotlib.patches.Wedge at 0x1a8c8f282e0>,
# ...
#  [Text(-1.2106016300689784, 0.47375488733556376, 'Yes'),
#   Text(1.0243552348260097, -0.4008694960764047, 'No')])

# %%
sns.countplot(data=df,x="Attrition")
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %%
#Drop the unwanted columns
df = df.drop(['EmployeeCount','EmployeeID'],axis='columns')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41        No      Travel_Rarely       1102  Cardiology                 1
# 1   49        No  Travel_Frequently        279   Maternity                 8
# 2   37       Yes      Travel_Rarely       1373   Maternity                 2
# 3   33        No  Travel_Frequently       1392   Maternity                 3
# 4   27        No      Travel_Rarely        591   Maternity                 2
#
#    Education EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0          2  Life Sciences                        2  Female  ...
# 1          1  Life Sciences                        3    Male  ...
# 2          2          Other                        4    Male  ...
# 3          4  Life Sciences                        4  Female  ...
# 4          1        Medical                        1    Male  ...
#
#    RelationshipSatisfaction  StandardHours  Shift TotalWorkingYears  \
# ...

# %%
attrition_dummies = pd.get_dummies(df.Attrition)
attrition_dummies.head()
# Out:
#    No  Yes
# 0   1    0
# 1   1    0
# 2   0    1
# 3   1    0
# 4   1    0

# %%
df = pd.concat([df,attrition_dummies],axis=1)

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41        No      Travel_Rarely       1102  Cardiology                 1
# 1   49        No  Travel_Frequently        279   Maternity                 8
# 2   37       Yes      Travel_Rarely       1373   Maternity                 2
# 3   33        No  Travel_Frequently       1392   Maternity                 3
# 4   27        No      Travel_Rarely        591   Maternity                 2
#
#    Education EducationField  EnvironmentSatisfaction  Gender  ...  Shift  \
# 0          2  Life Sciences                        2  Female  ...      0
# 1          1  Life Sciences                        3    Male  ...      1
# 2          2          Other                        4    Male  ...      0
# 3          4  Life Sciences                        4  Female  ...      0
# 4          1        Medical                        1    Male  ...      1
#
# ...

# %%
df.drop(['Attrition','No'],axis=1, inplace=True)

# %%
df.head()
# Out:
#    Age     BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   41      Travel_Rarely       1102  Cardiology                 1          2
# 1   49  Travel_Frequently        279   Maternity                 8          1
# 2   37      Travel_Rarely       1373   Maternity                 2          2
# 3   33  Travel_Frequently       1392   Maternity                 3          4
# 4   27      Travel_Rarely        591   Maternity                 2          1
#
#   EducationField  EnvironmentSatisfaction  Gender  HourlyRate  ...  \
# 0  Life Sciences                        2  Female          94  ...
# 1  Life Sciences                        3    Male          61  ...
# 2          Other                        4    Male          92  ...
# 3  Life Sciences                        4  Female          56  ...
# 4        Medical                        1    Male          40  ...
#
#    StandardHours  Shift TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %% [markdown]
# Now i just removed the NO and Attrition features , since the Yes feature says even the employee leave the company or not.

# %%
sns.barplot(data=df,x='Gender',y='Yes')
# Out:
# <Axes: xlabel='Gender', ylabel='Yes'>

# %%
sns.barplot(data=df,x='Department',y='Yes')
# Out:
# <Axes: xlabel='Department', ylabel='Yes'>

# %%
sns.barplot(x='BusinessTravel', y='Yes', data=df)
# Out:
# <Axes: xlabel='BusinessTravel', ylabel='Yes'>

# %%
df.drop (['Age', 'JobLevel'], axis=1, inplace=True)

# %%
df.head()
# Out:
#       BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      Travel_Rarely       1102  Cardiology                 1          2
# 1  Travel_Frequently        279   Maternity                 8          1
# 2      Travel_Rarely       1373   Maternity                 2          2
# 3  Travel_Frequently       1392   Maternity                 3          4
# 4      Travel_Rarely        591   Maternity                 2          1
#
#   EducationField  EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  \
# 0  Life Sciences                        2  Female          94               3
# 1  Life Sciences                        3    Male          61               2
# 2          Other                        4    Male          92               2
# 3  Life Sciences                        4  Female          56               3
# 4        Medical                        1    Male          40               3
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
for column in df.columns:
    if df[column].dtype==np.number:
        continue
    else:
        df[column]=LabelEncoder().fit_transform(df[column])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_30380\4259945406.py:3: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype==np.number:
# C:\Users\user\AppData\Local\Temp\ipykernel_30380\4259945406.py:3: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype==np.number:
# C:\Users\user\AppData\Local\Temp\ipykernel_30380\4259945406.py:3: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype==np.number:
# C:\Users\user\AppData\Local\Temp\ipykernel_30380\4259945406.py:3: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
# ...

# %%
df.head()
# Out:
#    BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0               2        624           0                 0          1
# 1               1        113           1                 7          0
# 2               2        805           1                 1          1
# 3               1        820           1                 2          3
# 4               2        312           1                 1          0
#
#    EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0               1                        1       0          64
# 1               1                        2       1          31
# 2               4                        3       1          62
# 3               1                        3       0          26
# 4               3                        0       1          10
#
#    JobInvolvement  ...  StandardHours  Shift  TotalWorkingYears  \
# 0               2  ...              0      0                  8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1676 entries, 0 to 1675
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   BusinessTravel            1676 non-null   int32
#  1   DailyRate                 1676 non-null   int64
#  2   Department                1676 non-null   int32
#  3   DistanceFromHome          1676 non-null   int64
#  4   Education                 1676 non-null   int64
#  5   EducationField            1676 non-null   int32
#  6   EnvironmentSatisfaction   1676 non-null   int64
#  7   Gender                    1676 non-null   int32
#  8   HourlyRate                1676 non-null   int64
#  9   JobInvolvement            1676 non-null   int64
#  10  JobRole                   1676 non-null   int32
#  11  JobSatisfaction           1676 non-null   int64
#  12  MaritalStatus             1676 non-null   int32
#  13  MonthlyIncome             1676 non-null   int64
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
X=df.drop('Yes',axis=1)
Y = df.Yes

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3)

# %%
model = RandomForestClassifier()

# %%
model.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
model.score(X_test,Y_test)
# Out:
# 0.9304174950298211

# %%
from sklearn.svm import SVC
model2 = SVC()

# %%
model2.fit(X_train,Y_train)
# Out:
# SVC()

# %%
model2.score(X_test,Y_test)
# Out:
# 0.8727634194831014

# %%
model3 = SVC(kernel='linear')

# %%
model3.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
model3.score(X_test,Y_test)
# Out:
# 0.9145129224652088
